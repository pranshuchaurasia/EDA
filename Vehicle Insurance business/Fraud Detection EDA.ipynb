# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as ply

# %%
df=pd.read_csv(r'C:\Users\Pranshu Chaurasia\OneDrive\Desktop\Projects\Vehicle Insurance business\AnalyticsOlympiad2022Data\test.csv')

# %%
df.head()
# Out:
#        ID    AGE  GENDER DRIVING_EXPERIENCE    EDUCATION         INCOME  \
# 0  352928  40-64    male             10-19y         none  working class
# 1   38579  26-39  female             20-29y  high school    upper class
# 2  504022  40-64    male             10-19y         none    upper class
# 3  202404  26-39    male             20-29y  high school    upper class
# 4  527913    65+    male             10-19y         none   middle class
#
#    CREDIT_SCORE  VEHICLE_OWNERSHIP VEHICLE_YEAR  MARRIED  CHILDREN  \
# 0      0.814707                1.0   after 2015      0.0       1.0
# 1      0.344051                1.0  before 2015      0.0       0.0
# 2      0.620691                0.0   after 2015      1.0       0.0
# 3      0.689658                1.0   after 2015      1.0       1.0
# 4      0.755666                0.0   after 2015      0.0       1.0
#
#    POSTAL_CODE  ANNUAL_MILEAGE  SPEEDING_VIOLATIONS  DUIS  PAST_ACCIDENTS  \
# 0        10238         10000.0                    0     0               0
# 1        34073         13000.0                    0     0               0
# 2        10238         12000.0                    0     0               0
# 3        10238         16000.0                    1     0               0
# 4        92101         14000.0                    2     0               0
#
#   TYPE_OF_VEHICLE
# 0       HatchBack
# 1           Sedan
# 2             SUV
# 3             SUV
# 4       HatchBack

# %%
df.tail()
# Out:
#            ID    AGE  GENDER DRIVING_EXPERIENCE    EDUCATION         INCOME  \
# 44995  117683    65+  female             20-29y  high school        poverty
# 44996  619620  40-64    male             20-29y   university  working class
# 44997   11086  40-64    male             10-19y         none        poverty
# 44998   31717    65+    male               30y+  high school    upper class
# 44999   26945    65+  female             10-19y  high school    upper class
#
#        CREDIT_SCORE  VEHICLE_OWNERSHIP VEHICLE_YEAR  MARRIED  CHILDREN  \
# 44995      0.472022                1.0  before 2015      1.0       0.0
# 44996      0.757312                0.0  before 2015      1.0       0.0
# 44997      0.566764                0.0   after 2015      0.0       0.0
# 44998      0.741850                1.0  before 2015      1.0       0.0
# 44999      0.705271                1.0   after 2015      1.0       1.0
#
#        POSTAL_CODE  ANNUAL_MILEAGE  SPEEDING_VIOLATIONS  DUIS  PAST_ACCIDENTS  \
# 44995        10238         10000.0                    0     0               1
# 44996        10238         12000.0                    0     0               0
# 44997        10238         13000.0                    0     0               0
# 44998        92101         13000.0                    1     0               0
# 44999        10238          8000.0                    1     0               1
#
#       TYPE_OF_VEHICLE
# 44995      Sports Car
# 44996      Sports Car
# 44997           Sedan
# 44998      Sports Car
# 44999      Sports Car

# %%
df.shape
# Out:
# (45000, 17)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45000 entries, 0 to 44999
# Data columns (total 17 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   45000 non-null  int64
#  1   AGE                  45000 non-null  object
#  2   GENDER               45000 non-null  object
#  3   DRIVING_EXPERIENCE   45000 non-null  object
#  4   EDUCATION            45000 non-null  object
#  5   INCOME               45000 non-null  object
#  6   CREDIT_SCORE         45000 non-null  float64
#  7   VEHICLE_OWNERSHIP    45000 non-null  float64
#  8   VEHICLE_YEAR         45000 non-null  object
#  9   MARRIED              45000 non-null  float64
#  10  CHILDREN             45000 non-null  float64
#  11  POSTAL_CODE          45000 non-null  int64
#  12  ANNUAL_MILEAGE       45000 non-null  float64
#  13  SPEEDING_VIOLATIONS  45000 non-null  int64
#  14  DUIS                 45000 non-null  int64
#  15  PAST_ACCIDENTS       45000 non-null  int64
#  16  TYPE_OF_VEHICLE      45000 non-null  object
# dtypes: float64(5), int64(5), object(7)
# memory usage: 5.8+ MB

# %%
df.columns
# Out:
# Index(['ID', 'AGE', 'GENDER', 'DRIVING_EXPERIENCE', 'EDUCATION', 'INCOME',
#        'CREDIT_SCORE', 'VEHICLE_OWNERSHIP', 'VEHICLE_YEAR', 'MARRIED',
#        'CHILDREN', 'POSTAL_CODE', 'ANNUAL_MILEAGE', 'SPEEDING_VIOLATIONS',
#        'DUIS', 'PAST_ACCIDENTS', 'TYPE_OF_VEHICLE'],
#       dtype='object')

# %%
l= df.columns

# %%
type(l)
# Out:
# pandas.core.indexes.base.Index

# %%
df1=df

# %%
df.drop('ID',axis=1)
# Out:
#          AGE  GENDER DRIVING_EXPERIENCE    EDUCATION         INCOME  \
# 0      40-64    male             10-19y         none  working class
# 1      26-39  female             20-29y  high school    upper class
# 2      40-64    male             10-19y         none    upper class
# 3      26-39    male             20-29y  high school    upper class
# 4        65+    male             10-19y         none   middle class
# ...      ...     ...                ...          ...            ...
# 44995    65+  female             20-29y  high school        poverty
# 44996  40-64    male             20-29y   university  working class
# 44997  40-64    male             10-19y         none        poverty
# 44998    65+    male               30y+  high school    upper class
# 44999    65+  female             10-19y  high school    upper class
#
#        CREDIT_SCORE  VEHICLE_OWNERSHIP VEHICLE_YEAR  MARRIED  CHILDREN  \
# 0          0.814707                1.0   after 2015      0.0       1.0
# 1          0.344051                1.0  before 2015      0.0       0.0
# 2          0.620691                0.0   after 2015      1.0       0.0
# 3          0.689658                1.0   after 2015      1.0       1.0
# 4          0.755666                0.0   after 2015      0.0       1.0
# ...             ...                ...          ...      ...       ...
# 44995      0.472022                1.0  before 2015      1.0       0.0
# 44996      0.757312                0.0  before 2015      1.0       0.0
# 44997      0.566764                0.0   after 2015      0.0       0.0
# 44998      0.741850                1.0  before 2015      1.0       0.0
# 44999      0.705271                1.0   after 2015      1.0       1.0
#
#        POSTAL_CODE  ANNUAL_MILEAGE  SPEEDING_VIOLATIONS  DUIS  PAST_ACCIDENTS  \
# 0            10238         10000.0                    0     0               0
# 1            34073         13000.0                    0     0               0
# 2            10238         12000.0                    0     0               0
# 3            10238         16000.0                    1     0               0
# 4            92101         14000.0                    2     0               0
# ...            ...             ...                  ...   ...             ...
# 44995        10238         10000.0                    0     0               1
# 44996        10238         12000.0                    0     0               0
# 44997        10238         13000.0                    0     0               0
# 44998        92101         13000.0                    1     0               0
# 44999        10238          8000.0                    1     0               1
#
#       TYPE_OF_VEHICLE
# 0           HatchBack
# 1               Sedan
# 2                 SUV
# 3                 SUV
# 4           HatchBack
# ...               ...
# 44995      Sports Car
# 44996      Sports Car
# 44997           Sedan
# 44998      Sports Car
# 44999      Sports Car
#
# [45000 rows x 16 columns]

# %%
df.head()
# Out:
#        ID    AGE  GENDER DRIVING_EXPERIENCE    EDUCATION         INCOME  \
# 0  352928  40-64    male             10-19y         none  working class
# 1   38579  26-39  female             20-29y  high school    upper class
# 2  504022  40-64    male             10-19y         none    upper class
# 3  202404  26-39    male             20-29y  high school    upper class
# 4  527913    65+    male             10-19y         none   middle class
#
#    CREDIT_SCORE  VEHICLE_OWNERSHIP VEHICLE_YEAR  MARRIED  CHILDREN  \
# 0      0.814707                1.0   after 2015      0.0       1.0
# 1      0.344051                1.0  before 2015      0.0       0.0
# 2      0.620691                0.0   after 2015      1.0       0.0
# 3      0.689658                1.0   after 2015      1.0       1.0
# 4      0.755666                0.0   after 2015      0.0       1.0
#
#    POSTAL_CODE  ANNUAL_MILEAGE  SPEEDING_VIOLATIONS  DUIS  PAST_ACCIDENTS  \
# 0        10238         10000.0                    0     0               0
# 1        34073         13000.0                    0     0               0
# 2        10238         12000.0                    0     0               0
# 3        10238         16000.0                    1     0               0
# 4        92101         14000.0                    2     0               0
#
#   TYPE_OF_VEHICLE
# 0       HatchBack
# 1           Sedan
# 2             SUV
# 3             SUV
# 4       HatchBack

# %%
df.isnull().sum()
# Out:
# ID                     0
# AGE                    0
# GENDER                 0
# DRIVING_EXPERIENCE     0
# EDUCATION              0
# INCOME                 0
# CREDIT_SCORE           0
# VEHICLE_OWNERSHIP      0
# VEHICLE_YEAR           0
# MARRIED                0
# CHILDREN               0
# POSTAL_CODE            0
# ANNUAL_MILEAGE         0
# SPEEDING_VIOLATIONS    0
# DUIS                   0
# PAST_ACCIDENTS         0
# TYPE_OF_VEHICLE        0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45000 entries, 0 to 44999
# Data columns (total 17 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   45000 non-null  int64
#  1   AGE                  45000 non-null  object
#  2   GENDER               45000 non-null  object
#  3   DRIVING_EXPERIENCE   45000 non-null  object
#  4   EDUCATION            45000 non-null  object
#  5   INCOME               45000 non-null  object
#  6   CREDIT_SCORE         45000 non-null  float64
#  7   VEHICLE_OWNERSHIP    45000 non-null  float64
#  8   VEHICLE_YEAR         45000 non-null  object
#  9   MARRIED              45000 non-null  float64
#  10  CHILDREN             45000 non-null  float64
#  11  POSTAL_CODE          45000 non-null  int64
#  12  ANNUAL_MILEAGE       45000 non-null  float64
#  13  SPEEDING_VIOLATIONS  45000 non-null  int64
#  14  DUIS                 45000 non-null  int64
#  15  PAST_ACCIDENTS       45000 non-null  int64
#  16  TYPE_OF_VEHICLE      45000 non-null  object
# dtypes: float64(5), int64(5), object(7)
# memory usage: 5.8+ MB

# %%
df.nunique()
# Out:
# ID                     43692
# AGE                        4
# GENDER                     2
# DRIVING_EXPERIENCE         4
# EDUCATION                  3
# INCOME                     4
# CREDIT_SCORE           44994
# VEHICLE_OWNERSHIP          2
# VEHICLE_YEAR               2
# MARRIED                    2
# CHILDREN                   2
# POSTAL_CODE             7003
# ANNUAL_MILEAGE            20
# SPEEDING_VIOLATIONS       18
# DUIS                       7
# PAST_ACCIDENTS            16
# TYPE_OF_VEHICLE            4
# dtype: int64

# %%
df['AGE'].unique()
# Out:
# array(['40-64', '26-39', '65+', '16-25'], dtype=object)

# %%
for i in df.columns:
    print(i, df[i].unique())
# Out:
# ID [352928  38579 504022 ...  11086  31717  26945]
# AGE ['40-64' '26-39' '65+' '16-25']
# GENDER ['male' 'female']
# DRIVING_EXPERIENCE ['10-19y' '20-29y' '0-9y' '30y+']
# EDUCATION ['none' 'high school' 'university']
# INCOME ['working class' 'upper class' 'middle class' 'poverty']
# CREDIT_SCORE [0.81470683 0.34405065 0.62069051 ... 0.56676379 0.74185008 0.70527116]
# VEHICLE_OWNERSHIP [1. 0.]
# VEHICLE_YEAR ['after 2015' 'before 2015']
# MARRIED [0. 1.]
# CHILDREN [1. 0.]
# POSTAL_CODE [10238 34073 92101 ... 90626 34313 30617]
# ANNUAL_MILEAGE [10000. 13000. 12000. 16000. 14000.  7000.  9000. 11000.  4000.  3000.
#  15000.  8000.  6000.  5000. 18000. 17000.  2000. 19000. 21000. 20000.]
# SPEEDING_VIOLATIONS [ 0  1  2  4 10  3  5  6 12  8 11  7  9 14 15 13 17 16]
# DUIS [0 1 3 6 2 4 5]
# PAST_ACCIDENTS [ 0  7  3  1  2  4  8  5 12  6 11  9 13 10 14 15]
# TYPE_OF_VEHICLE ['HatchBack' 'Sedan' 'SUV' 'Sports Car']

# %%
df.describe()
# Out:
#                   ID  CREDIT_SCORE  VEHICLE_OWNERSHIP       MARRIED  \
# count   45000.000000  45000.000000       45000.000000  45000.000000
# mean   395395.324133      0.601959           0.826800      0.582644
# std    280943.713918      0.137370           0.378424      0.493128
# min       101.000000      0.063765           0.000000      0.000000
# 25%    153667.000000      0.514618           1.000000      0.000000
# 50%    353790.500000      0.599917           1.000000      1.000000
# 75%    599984.750000      0.702565           1.000000      1.000000
# max    999976.000000      0.951822           1.000000      1.000000
#
#            CHILDREN   POSTAL_CODE  ANNUAL_MILEAGE  SPEEDING_VIOLATIONS  \
# count  45000.000000  45000.000000    45000.000000         45000.000000
# mean       0.523956  17974.772733    11084.177778             0.688844
# std        0.499431  16630.476937     2966.584026             1.422621
# min        0.000000  10238.000000     2000.000000             0.000000
# 25%        0.000000  10238.000000     9000.000000             0.000000
# 50%        1.000000  10238.000000    11000.000000             0.000000
# 75%        1.000000  21304.000000    13000.000000             1.000000
# max        1.000000  92101.000000    21000.000000            17.000000
#
#                DUIS  PAST_ACCIDENTS
# count  45000.000000    45000.000000
# mean       0.130244        0.548933
# std        0.592996        1.381562
# min        0.000000        0.000000
# 25%        0.000000        0.000000
# 50%        0.000000        0.000000
# 75%        0.000000        1.000000
# max        6.000000       15.000000

# %%
df.describe().T
# Out:
#                        count           mean            std           min  \
# ID                   45000.0  395395.324133  280943.713918    101.000000
# CREDIT_SCORE         45000.0       0.601959       0.137370      0.063765
# VEHICLE_OWNERSHIP    45000.0       0.826800       0.378424      0.000000
# MARRIED              45000.0       0.582644       0.493128      0.000000
# CHILDREN             45000.0       0.523956       0.499431      0.000000
# POSTAL_CODE          45000.0   17974.772733   16630.476937  10238.000000
# ANNUAL_MILEAGE       45000.0   11084.177778    2966.584026   2000.000000
# SPEEDING_VIOLATIONS  45000.0       0.688844       1.422621      0.000000
# DUIS                 45000.0       0.130244       0.592996      0.000000
# PAST_ACCIDENTS       45000.0       0.548933       1.381562      0.000000
#
#                                25%            50%            75%  \
# ID                   153667.000000  353790.500000  599984.750000
# CREDIT_SCORE              0.514618       0.599917       0.702565
# VEHICLE_OWNERSHIP         1.000000       1.000000       1.000000
# MARRIED                   0.000000       1.000000       1.000000
# CHILDREN                  0.000000       1.000000       1.000000
# POSTAL_CODE           10238.000000   10238.000000   21304.000000
# ANNUAL_MILEAGE         9000.000000   11000.000000   13000.000000
# SPEEDING_VIOLATIONS       0.000000       0.000000       1.000000
# DUIS                      0.000000       0.000000       0.000000
# PAST_ACCIDENTS            0.000000       0.000000       1.000000
#
#                                max
# ID                   999976.000000
# CREDIT_SCORE              0.951822
# VEHICLE_OWNERSHIP         1.000000
# MARRIED                   1.000000
# CHILDREN                  1.000000
# POSTAL_CODE           92101.000000
# ANNUAL_MILEAGE        21000.000000
# SPEEDING_VIOLATIONS      17.000000
# DUIS                      6.000000
# PAST_ACCIDENTS           15.000000

# %%
df1=df1.drop('ID',axis=1)

# %%
for i in df1.columns:
    if(df1[i].dtype=='O'):
        df1= df1.drop(i,axis=1)

# %%
df1.corr()
# Out:
#                      CREDIT_SCORE  VEHICLE_OWNERSHIP   MARRIED  CHILDREN  \
# CREDIT_SCORE             1.000000          -0.000119  0.001156  0.007135
# VEHICLE_OWNERSHIP       -0.000119           1.000000 -0.013798 -0.000269
# MARRIED                  0.001156          -0.013798  1.000000 -0.006911
# CHILDREN                 0.007135          -0.000269 -0.006911  1.000000
# POSTAL_CODE             -0.008436          -0.015480 -0.002046 -0.010310
# ANNUAL_MILEAGE          -0.025792          -0.004749 -0.000578  0.013548
# SPEEDING_VIOLATIONS     -0.011408          -0.007312  0.002572 -0.004929
# DUIS                     0.000697           0.000508 -0.000447 -0.004795
# PAST_ACCIDENTS          -0.003244          -0.001301  0.000767  0.003261
#
#                      POSTAL_CODE  ANNUAL_MILEAGE  SPEEDING_VIOLATIONS  \
# CREDIT_SCORE           -0.008436       -0.025792            -0.011408
# VEHICLE_OWNERSHIP      -0.015480       -0.004749            -0.007312
# MARRIED                -0.002046       -0.000578             0.002572
# CHILDREN               -0.010310        0.013548            -0.004929
# POSTAL_CODE             1.000000        0.002789             0.008687
# ANNUAL_MILEAGE          0.002789        1.000000            -0.004241
# SPEEDING_VIOLATIONS     0.008687       -0.004241             1.000000
# DUIS                   -0.006126       -0.006232            -0.001747
# PAST_ACCIDENTS          0.003063        0.002411             0.003812
#
#                          DUIS  PAST_ACCIDENTS
# CREDIT_SCORE         0.000697       -0.003244
# VEHICLE_OWNERSHIP    0.000508       -0.001301
# MARRIED             -0.000447        0.000767
# CHILDREN            -0.004795        0.003261
# POSTAL_CODE         -0.006126        0.003063
# ANNUAL_MILEAGE      -0.006232        0.002411
# SPEEDING_VIOLATIONS -0.001747        0.003812
# DUIS                 1.000000        0.003979
# PAST_ACCIDENTS       0.003979        1.000000

# %%
import seaborn as sns

# %%
df1=df1.drop('AGE',axis=1)
df1=df1.drop('AGE',axis=1)

# %%
df1
# Out:
#        CREDIT_SCORE  VEHICLE_OWNERSHIP  MARRIED  CHILDREN  POSTAL_CODE  \
# 0          0.814707                1.0      0.0       1.0        10238
# 1          0.344051                1.0      0.0       0.0        34073
# 2          0.620691                0.0      1.0       0.0        10238
# 3          0.689658                1.0      1.0       1.0        10238
# 4          0.755666                0.0      0.0       1.0        92101
# ...             ...                ...      ...       ...          ...
# 44995      0.472022                1.0      1.0       0.0        10238
# 44996      0.757312                0.0      1.0       0.0        10238
# 44997      0.566764                0.0      0.0       0.0        10238
# 44998      0.741850                1.0      1.0       0.0        92101
# 44999      0.705271                1.0      1.0       1.0        10238
#
#        ANNUAL_MILEAGE  SPEEDING_VIOLATIONS  DUIS  PAST_ACCIDENTS
# 0             10000.0                    0     0               0
# 1             13000.0                    0     0               0
# 2             12000.0                    0     0               0
# 3             16000.0                    1     0               0
# 4             14000.0                    2     0               0
# ...               ...                  ...   ...             ...
# 44995         10000.0                    0     0               1
# 44996         12000.0                    0     0               0
# 44997         13000.0                    0     0               0
# 44998         13000.0                    1     0               0
# 44999          8000.0                    1     0               1
#
# [45000 rows x 9 columns]

# %%
ply.figure(figsize = (20,20))
sns.heatmap(df1)
# Out:
# <AxesSubplot:>

# %%
df1.cov()
# Out:
#                      CREDIT_SCORE  VEHICLE_OWNERSHIP    MARRIED   CHILDREN  \
# CREDIT_SCORE             0.018870          -0.000006   0.000078   0.000490
# VEHICLE_OWNERSHIP       -0.000006           0.143205  -0.002575  -0.000051
# MARRIED                  0.000078          -0.002575   0.243175  -0.001702
# CHILDREN                 0.000490          -0.000051  -0.001702   0.249432
# POSTAL_CODE            -19.271431         -97.422861 -16.782491 -85.632848
# ANNUAL_MILEAGE         -10.510879          -5.331638  -0.845733  20.072810
# SPEEDING_VIOLATIONS     -0.002229          -0.003937   0.001804  -0.003502
# DUIS                     0.000057           0.000114  -0.000131  -0.001420
# PAST_ACCIDENTS          -0.000616          -0.000680   0.000523   0.002250
#
#                       POSTAL_CODE  ANNUAL_MILEAGE  SPEEDING_VIOLATIONS  \
# CREDIT_SCORE        -1.927143e+01   -1.051088e+01            -0.002229
# VEHICLE_OWNERSHIP   -9.742286e+01   -5.331638e+00            -0.003937
# MARRIED             -1.678249e+01   -8.457334e-01             0.001804
# CHILDREN            -8.563285e+01    2.007281e+01            -0.003502
# POSTAL_CODE          2.765728e+08    1.375909e+05           205.520007
# ANNUAL_MILEAGE       1.375909e+05    8.800621e+06           -17.896903
# SPEEDING_VIOLATIONS  2.055200e+02   -1.789690e+01             2.023849
# DUIS                -6.041048e+01   -1.096393e+01            -0.001474
# PAST_ACCIDENTS       7.038496e+01    9.881120e+00             0.007493
#
#                           DUIS  PAST_ACCIDENTS
# CREDIT_SCORE          0.000057       -0.000616
# VEHICLE_OWNERSHIP     0.000114       -0.000680
# MARRIED              -0.000131        0.000523
# CHILDREN             -0.001420        0.002250
# POSTAL_CODE         -60.410476       70.384963
# ANNUAL_MILEAGE      -10.963932        9.881120
# SPEEDING_VIOLATIONS  -0.001474        0.007493
# DUIS                  0.351644        0.003260
# PAST_ACCIDENTS        0.003260        1.908715

# %%
df1=df1.drop('POSTAL_CODE',axis=1)

# %%
df1.cov()
# Out:
#                      CREDIT_SCORE  VEHICLE_OWNERSHIP   MARRIED   CHILDREN  \
# CREDIT_SCORE             0.018870          -0.000006  0.000078   0.000490
# VEHICLE_OWNERSHIP       -0.000006           0.143205 -0.002575  -0.000051
# MARRIED                  0.000078          -0.002575  0.243175  -0.001702
# CHILDREN                 0.000490          -0.000051 -0.001702   0.249432
# ANNUAL_MILEAGE         -10.510879          -5.331638 -0.845733  20.072810
# SPEEDING_VIOLATIONS     -0.002229          -0.003937  0.001804  -0.003502
# DUIS                     0.000057           0.000114 -0.000131  -0.001420
# PAST_ACCIDENTS          -0.000616          -0.000680  0.000523   0.002250
#
#                      ANNUAL_MILEAGE  SPEEDING_VIOLATIONS       DUIS  \
# CREDIT_SCORE          -1.051088e+01            -0.002229   0.000057
# VEHICLE_OWNERSHIP     -5.331638e+00            -0.003937   0.000114
# MARRIED               -8.457334e-01             0.001804  -0.000131
# CHILDREN               2.007281e+01            -0.003502  -0.001420
# ANNUAL_MILEAGE         8.800621e+06           -17.896903 -10.963932
# SPEEDING_VIOLATIONS   -1.789690e+01             2.023849  -0.001474
# DUIS                  -1.096393e+01            -0.001474   0.351644
# PAST_ACCIDENTS         9.881120e+00             0.007493   0.003260
#
#                      PAST_ACCIDENTS
# CREDIT_SCORE              -0.000616
# VEHICLE_OWNERSHIP         -0.000680
# MARRIED                    0.000523
# CHILDREN                   0.002250
# ANNUAL_MILEAGE             9.881120
# SPEEDING_VIOLATIONS        0.007493
# DUIS                       0.003260
# PAST_ACCIDENTS             1.908715

# %%
df.columns
# Out:
# Index(['ID', 'AGE', 'GENDER', 'DRIVING_EXPERIENCE', 'EDUCATION', 'INCOME',
#        'CREDIT_SCORE', 'VEHICLE_OWNERSHIP', 'VEHICLE_YEAR', 'MARRIED',
#        'CHILDREN', 'POSTAL_CODE', 'ANNUAL_MILEAGE', 'SPEEDING_VIOLATIONS',
#        'DUIS', 'PAST_ACCIDENTS', 'TYPE_OF_VEHICLE'],
#       dtype='object')

# %%
# Out:
#        OUTCOME
# 44995      0.0
# 44996      0.0
# 44997      0.0
# 44998      0.0
# 44999      0.0
